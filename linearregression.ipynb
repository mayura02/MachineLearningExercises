# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

def genData(n_samples=100):
    rnd = np.random.RandomState(42)
    x = rnd.uniform(-3,3,size=n_samples)
    y_no_noise = 4*x # (np.sin(4*x)+x)
    y = (y_no_noise + rnd.normal(size = len(x)))/2
    return x.reshape(-1,1),y

X,y = genData(100)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)
print(X)
print(':)')
print(y)


lr = LinearRegression()

lr.fit(X_train, y_train)

y_hat = lr.predict(X_test)

#print(list(zip(y_hat,y_test)))

print(lr.score(X_test,y_test))
# Out:
# [[-0.75275929]
#  [ 2.70428584]
#  [ 1.39196365]
#  [ 0.59195091]
#  [-2.06388816]
#  [-2.06403288]
#  [-2.65149833]
#  [ 2.19705687]
#  [ 0.60669007]
#  [ 1.24843547]
#  [-2.87649303]
#  [ 2.81945911]
#  [ 1.99465584]
#  [-1.72596534]
#  [-1.9090502 ]
#  [-1.89957294]
#  [-1.17454654]
#  [ 0.14853859]
#  [-0.40832989]
#  [-1.25262516]
#  [ 0.67111737]
#  [-2.16303684]
#  [-1.24713211]
#  [-0.80182894]
#  [-0.26358009]
#  [ 1.71105577]
#  [-1.80195731]
#  [ 0.08540663]
#  [ 0.55448741]
#  [-2.72129752]
#  [ 0.64526911]
#  [-1.97685526]
#  [-2.60969044]
#  [ 2.69331322]
#  [ 2.7937922 ]
#  [ 1.85038409]
#  [-1.17231738]
#  [-2.41396732]
#  [ 1.10539816]
#  [-0.35908504]
#  [-2.26777059]
#  [-0.02893854]
#  [-2.79366887]
#  [ 2.45592241]
#  [-1.44732011]
#  [ 0.97513371]
#  [-1.12973354]
#  [ 0.12040813]
#  [ 0.28026168]
#  [-1.89087327]
#  [ 2.81750777]
#  [ 1.65079694]
#  [ 2.63699365]
#  [ 2.3689641 ]
#  [ 0.58739987]
#  [ 2.53124541]
#  [-2.46904499]
#  [-1.82410283]
# ...

# %%
# Writing Linear Regression Code from scratch



import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

def generateLinearData():
    rnd = np.random.RandomState(42)
    x = np.random.uniform(-5,5,100).round(3)
    y = x*12+4
    return x.reshape(-1,1),y



X,y = generateLinearData()

#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

a = 100
b = 150

learning_rate = 0.001

aa = a
bb = b

for x in range(200):
  y_hat = X*a + b
  Loss_b = 0
  Loss_a = 0

  for i in range(len(X)):
    Loss_b = Loss_b + (y_hat[i] - y[i])
    #print("Loss_b = ",Loss_b)

  b = b - learning_rate*Loss_b

  for i in range(len(X)):
    Loss_a = Loss_a + (y_hat[i] - y[i])*X[i]
   # print("Loss_a = ",Loss_a)

  a = a - learning_rate*Loss_a
#  print("Loss a = ",Loss_a, " Loss b = ",Loss_b)
  print("round ",x," a=",a," b=",b)


print((5*a+b))

a = aa
b = bb

for x in range(200):

  Loss_b = 0
  Loss_a = 0

  k = 20

  for t in range(len(X)//k):
    y_hat = X*a + b
    for i in range((t-1)*k+1,t*k):
      Loss_b = Loss_b + (y_hat[i] - y[i])

    b = b - learning_rate*Loss_b

    for i in range((t-1)*k+1,t*k):
      Loss_a = Loss_a + (y_hat[i] - y[i])*X[i]

    a = a - learning_rate*Loss_a
  #  print("Loss a = ",Loss_a, " Loss b = ",Loss_b)
  print("round ",x," a=",a," b=",b)
# Out:
# round  0  a= [35.39788242]  b= [136.272608]
# round  1  a= [19.14783046]  b= [123.2773606]
# round  2  a= [14.96566255]  b= [111.42050243]
# round  3  a= [13.80491724]  b= [100.7078597]
# round  4  a= [13.40916193]  b= [91.05497129]
# round  5  a= [13.21472926]  b= [82.36344741]
# round  6  a= [13.08004609]  b= [74.53914792]
# round  7  a= [12.96886585]  b= [67.49594287]
# round  8  a= [12.87129335]  b= [61.15595585]
# round  9  a= [12.78408819]  b= [55.44900001]
# round  10  a= [12.70574613]  b= [50.31187503]
# round  11  a= [12.63526527]  b= [45.68768571]
# round  12  a= [12.57183152]  b= [41.52521643]
# round  13  a= [12.51473397]  b= [37.77836506]
# round  14  a= [12.46333816]  b= [34.40563266]
# round  15  a= [12.4170743]  b= [31.36966386]
# round  16  a= [12.37542988]  b= [28.63683318]
# round  17  a= [12.33794362]  b= [26.17687262]
# round  18  a= [12.30420032]  b= [23.96253641]
# round  19  a= [12.27382626]  b= [21.96929922]
# round  20  a= [12.24648501]  b= [20.17508456]
# ...
